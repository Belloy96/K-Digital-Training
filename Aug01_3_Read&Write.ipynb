# %% [markdown]
# <a href="https://colab.research.google.com/github/Belloy96/K-Digital-Training/blob/master/Aug01_3_Read%26Write.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # 1. csv파일 읽고 쓰기
#
# # 1-1. 쓰기 (to_csv)
#
# 데이터프레임을 만들고 scv파일에 저장

# %%
df = pd.DataFrame({'A' : [0, 1, 2], 'B' : [1, 2, 3], 'C' : [4, 5, 6], 'D' : [7, 8, 9]})
df.to_csv('test.csv', index = False)
df

# index=False 옵션은 데이터프레임에 자동으로 추가된 인덱스가 없이 저장
dff = pd.DataFrame({'A' : [0, 1, 2], 'B' : [1, 2, 3], 'C' : [4, 5, 6], 'D' : [7, 8, 9]})
dff.to_csv('test2.csv') # index=False를 넣지 않고 생성했을 때의 경우
dff
# Out:
#    A  B  C  D
# 0  0  1  4  7
# 1  1  2  5  8
# 2  2  3  6  9

# %% [markdown]
# # 1-2. 읽기 (read_csv)

# %%
df1 = pd.read_csv('test.csv')
df1
# Out:
#    A  B  C  D
# 0  0  1  4  7
# 1  1  2  5  8
# 2  2  3  6  9

# %%
# read_csv() 함수는 첫 번째 행을 header(열이름)로 지정해서 불러옴
# 불러올 데이터에 header가 없다면 header = None 옵션을 줘야함 !

df2 = pd.read_csv('test.csv', header=None)
df2
# Out:
#    0  1  2  3
# 0  A  B  C  D
# 1  0  1  4  7
# 2  1  2  5  8
# 3  2  3  6  9

# %%
# index_col 옵션은 기본값은 None이고,이 때 새로운 정수 0, 1, 2, ... 를 생성
# index_col = 'C' 를 옵션으로 줄 경우, C열을 인덱스로 불러서 사용

df3 = pd.read_csv('test.csv', index_col = 'C')
df3
# Out:
#    A  B  D
# C
# 4  0  1  7
# 5  1  2  8
# 6  2  3  9

# %%
# names = ['열이름1', '열이름2', ...] 옵션을 통해 열 이름을 따로 설정할 수 있음
df4 = pd.read_csv('test.csv', names = ['1열', '2열', '3열', '4열'])
df4
# Out:
#   1열 2열 3열 4열
# 0  A  B  C  D
# 1  0  1  4  7
# 2  1  2  5  8
# 3  2  3  6  9

# %% [markdown]
# # 1-3. 다양한 옵션
#
# read_csv()의 다양한 옵션은 Pandas 공식 홈페이지에서 상세하게 보여줌
#
# 많이 쓰이는 옵션들 간단하게 정리... (default 기준)
#
# - sep(',') : 자료의 구분 기준을 설정
# - header('infer') : 첫 행을 열 이름으로 쓸 것인지
# - names : 열 이름을 리스트로 입력해 줄 수 있음
# - index_col : 특정한 열 이름으로 인덱스를 지정
# - dtype : 개별 열 or 모든 열의 자료형 지정
# - na_values : 결측값(NaN)으로 인식할 문자 지정
# - keep_default_na(True) : 결측값을 포함할지 여부 결정
# - na_filter(True) : 결측값 탐지
# - nrows : 읽을 파일 행(row) 수
